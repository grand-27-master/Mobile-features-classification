# %% [markdown]
# <a href="https://towardsdatascience.com/feature-selection-techniques-in-machine-learning-with-python-f24e7da3f36e#:~:text=Feature%20Selection%20is%20the%20process,learn%20based%20on%20irrelevant%20features.">Feature selection</a><br>
# <a href="https://en.wikipedia.org/wiki/Chi-squared_test">Chi square test</a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest

import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv('mobile_train.csv')
data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
data.shape
# Out:
# (2000, 21)

# %%
data.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
x=data.iloc[:,:20]
y=data.iloc[:,-1]
x
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
best_features=SelectKBest(score_func=chi2,k=10)
best_features
# Out:
# SelectKBest(score_func=<function chi2 at 0x000002C6BD56ECA0>)

# %%
fit=best_features.fit(x,y)
fit.scores_
# Out:
# array([1.41298666e+04, 7.23232323e-01, 6.48365906e-01, 6.31010795e-01,
#        1.01351665e+01, 1.52157239e+00, 8.98391244e+01, 7.45819631e-01,
#        9.59728626e+01, 9.09755558e+00, 9.18605355e+00, 1.73635695e+04,
#        9.81058675e+03, 9.31267519e+05, 9.61487832e+00, 1.64803191e+01,
#        1.32364000e+01, 3.27642810e-01, 1.92842942e+00, 4.22090730e-01])

# %%
df=pd.DataFrame(fit.scores_)

# %%
df
# Out:
#                 0
# 0    14129.866576
# 1        0.723232
# 2        0.648366
# 3        0.631011
# 4       10.135166
# 5        1.521572
# 6       89.839124
# 7        0.745820
# 8       95.972863
# 9        9.097556
# 10       9.186054
# 11   17363.569536
# 12    9810.586750
# 13  931267.519053
# 14       9.614878
# 15      16.480319
# 16      13.236400
# 17       0.327643
# 18       1.928429
# 19       0.422091

# %%
df.sort_values(0,ascending=True)
# Out:
#                 0
# 17       0.327643
# 19       0.422091
# 3        0.631011
# 2        0.648366
# 1        0.723232
# 7        0.745820
# 5        1.521572
# 18       1.928429
# 9        9.097556
# 10       9.186054
# 14       9.614878
# 4       10.135166
# 16      13.236400
# 15      16.480319
# 6       89.839124
# 8       95.972863
# 12    9810.586750
# 0    14129.866576
# 11   17363.569536
# 13  931267.519053

# %%
df_columns=pd.DataFrame(x.columns)
df_columns
# Out:
#                 0
# 0   battery_power
# 1            blue
# 2     clock_speed
# 3        dual_sim
# 4              fc
# 5          four_g
# 6      int_memory
# 7           m_dep
# 8       mobile_wt
# 9         n_cores
# 10             pc
# 11      px_height
# 12       px_width
# 13            ram
# 14           sc_h
# 15           sc_w
# 16      talk_time
# 17        three_g
# 18   touch_screen
# 19           wifi

# %%
data_mix=pd.concat([df,df_columns],axis=1)
data_mix
# Out:
#                 0              0
# 0    14129.866576  battery_power
# 1        0.723232           blue
# 2        0.648366    clock_speed
# 3        0.631011       dual_sim
# 4       10.135166             fc
# 5        1.521572         four_g
# 6       89.839124     int_memory
# 7        0.745820          m_dep
# 8       95.972863      mobile_wt
# 9        9.097556        n_cores
# 10       9.186054             pc
# 11   17363.569536      px_height
# 12    9810.586750       px_width
# 13  931267.519053            ram
# 14       9.614878           sc_h
# 15      16.480319           sc_w
# 16      13.236400      talk_time
# 17       0.327643        three_g
# 18       1.928429   touch_screen
# 19       0.422091           wifi

# %%
data_mix.columns=['score','Features']
data_mix
# Out:
#             score       Features
# 0    14129.866576  battery_power
# 1        0.723232           blue
# 2        0.648366    clock_speed
# 3        0.631011       dual_sim
# 4       10.135166             fc
# 5        1.521572         four_g
# 6       89.839124     int_memory
# 7        0.745820          m_dep
# 8       95.972863      mobile_wt
# 9        9.097556        n_cores
# 10       9.186054             pc
# 11   17363.569536      px_height
# 12    9810.586750       px_width
# 13  931267.519053            ram
# 14       9.614878           sc_h
# 15      16.480319           sc_w
# 16      13.236400      talk_time
# 17       0.327643        three_g
# 18       1.928429   touch_screen
# 19       0.422091           wifi

# %%
data_mix.sort_values('score',ascending=True)
# Out:
#             score       Features
# 17       0.327643        three_g
# 19       0.422091           wifi
# 3        0.631011       dual_sim
# 2        0.648366    clock_speed
# 1        0.723232           blue
# 7        0.745820          m_dep
# 5        1.521572         four_g
# 18       1.928429   touch_screen
# 9        9.097556        n_cores
# 10       9.186054             pc
# 14       9.614878           sc_h
# 4       10.135166             fc
# 16      13.236400      talk_time
# 15      16.480319           sc_w
# 6       89.839124     int_memory
# 8       95.972863      mobile_wt
# 12    9810.586750       px_width
# 0    14129.866576  battery_power
# 11   17363.569536      px_height
# 13  931267.519053            ram

# %%
data_mix.plot(x='Features',y='score',kind='bar')%colors
plt.xlabel('features of phone')
plt.ylabel('ratings')
plt.show()
